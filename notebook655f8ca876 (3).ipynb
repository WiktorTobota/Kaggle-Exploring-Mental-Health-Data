# %% [markdown]
# ***MODEL***

# %%
#import bibliotek 
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
#inny sposób na uzupełnienie nulli 
from sklearn.impute import KNNImputer

# %%
# Load the data
train_df = pd.read_csv(r'train.csv')
test_df = pd.read_csv(r'test.csv')

train_df
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# 3                 Working Professional            Teacher                NaN
# 4                 Working Professional   Business Analyst                NaN
# ...                                ...                ...                ...
# 140695            Working Professional                NaN                NaN
# 140696            Working Professional     Content Writer                NaN
# 140697            Working Professional  Marketing Manager                NaN
# 140698            Working Professional            Plumber                NaN
# 140699                         Student                NaN                4.0
#
#         Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                 5.0   NaN                 NaN               2.0
# 1                 4.0   NaN                 NaN               3.0
# 2                 NaN  8.97                 2.0               NaN
# 3                 5.0   NaN                 NaN               1.0
# 4                 1.0   NaN                 NaN               1.0
# ...               ...   ...                 ...               ...
# 140695            5.0   NaN                 NaN               4.0
# 140696            5.0   NaN                 NaN               4.0
# 140697            3.0   NaN                 NaN               1.0
# 140698            5.0   NaN                 NaN               2.0
# 140699            NaN  9.24                 1.0               NaN
#
#            Sleep Duration Dietary Habits    Degree  \
# 0       More than 8 hours        Healthy       BHM
# 1       Less than 5 hours      Unhealthy       LLB
# 2               5-6 hours        Healthy   B.Pharm
# 3       Less than 5 hours       Moderate       BBA
# 4               5-6 hours      Unhealthy       BBA
# ...                   ...            ...       ...
# 140695          5-6 hours      Unhealthy  Class 12
# 140696          7-8 hours       Moderate    B.Tech
# 140697  More than 8 hours       Moderate     B.Com
# 140698          5-6 hours       Moderate        ME
# 140699  Less than 5 hours        Healthy       BCA
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                         No               1.0
# 1                                        Yes               7.0
# 2                                        Yes               3.0
# 3                                        Yes              10.0
# 4                                        Yes               9.0
# ...                                      ...               ...
# 140695                                    No               2.0
# 140696                                   Yes               6.0
# 140697                                    No               4.0
# 140698                                   Yes              10.0
# 140699                                   Yes               2.0
#
#         Financial Stress Family History of Mental Illness  Depression
# 0                    2.0                               No           0
# 1                    3.0                               No           1
# 2                    1.0                               No           1
# 3                    1.0                              Yes           1
# 4                    4.0                              Yes           0
# ...                  ...                              ...         ...
# 140695               4.0                              Yes           1
# 140696               5.0                              Yes           0
# 140697               4.0                               No           0
# 140698               1.0                               No           0
# 140699               3.0                              Yes           1
#
# [140700 rows x 20 columns]

# %%
#sortowanie
train_df.sort_values('Working Professional or Student')
test_df.sort_values('Working Professional or Student')
# Out:
#            id     Name  Gender   Age           City  \
# 26084  166784   Nikhil    Male  32.0         Mumbai
# 82355  223055    Aarav    Male  30.0  Visakhapatnam
# 14325  155025   Aarush    Male  31.0         Meerut
# 59478  200178   Aahana  Female  29.0      Faridabad
# 82357  223057  Ishaani  Female  34.0      Hyderabad
# ...       ...      ...     ...   ...            ...
# 34691  175391   Chirag    Male  20.0       Srinagar
# 34690  175390    Rishi    Male  57.0       Varanasi
# 34688  175388   Aditya    Male  29.0  Visakhapatnam
# 34712  175412  Lavanya  Female  43.0           Agra
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 26084                         Student                     NaN
# 82355                         Student                     NaN
# 14325                         Student                     NaN
# 59478                         Student                     NaN
# 82357                         Student                     NaN
# ...                               ...                     ...
# 34691            Working Professional                     NaN
# 34690            Working Professional                   Pilot
# 34688            Working Professional               Architect
# 34712            Working Professional          Content Writer
# 93799            Working Professional  Educational Consultant
#
#        Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 26084                3.0            NaN  5.51                 4.0
# 82355                4.0            NaN  7.25                 3.0
# 14325                5.0            NaN  9.21                 3.0
# 59478                5.0            NaN  5.16                 5.0
# 82357                2.0            NaN  5.72                 4.0
# ...                  ...            ...   ...                 ...
# 34691                NaN            5.0   NaN                 NaN
# 34690                NaN            3.0   NaN                 NaN
# 34688                NaN            1.0   NaN                 NaN
# 34712                NaN            3.0   NaN                 NaN
# 93799                NaN            5.0   NaN                 NaN
#
#        Job Satisfaction     Sleep Duration Dietary Habits    Degree  \
# 26084               NaN          5-6 hours       Moderate       MCA
# 82355               NaN          7-8 hours      Unhealthy       MHM
# 14325               NaN          7-8 hours      Unhealthy    B.Tech
# 59478               NaN  Less than 5 hours        Healthy      B.Ed
# 82357               NaN  Less than 5 hours       Moderate    B.Tech
# ...                 ...                ...            ...       ...
# 34691               1.0          7-8 hours        Healthy  Class 12
# 34690               1.0          7-8 hours       Moderate       MCA
# 34688               5.0          5-6 hours        Healthy    B.Arch
# 34712               2.0  More than 8 hours        Healthy      M.Ed
# 93799               2.0  More than 8 hours        Healthy      B.Ed
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 26084                                   Yes               9.0
# 82355                                   Yes               8.0
# 14325                                   Yes              12.0
# 59478                                   Yes               4.0
# 82357                                    No              10.0
# ...                                     ...               ...
# 34691                                   Yes               2.0
# 34690                                   Yes              11.0
# 34688                                   Yes               2.0
# 34712                                   Yes               5.0
# 93799                                    No              11.0
#
#        Financial Stress Family History of Mental Illness
# 26084               1.0                              Yes
# 82355               3.0                               No
# 14325               3.0                              Yes
# 59478               4.0                               No
# 82357               1.0                              Yes
# ...                 ...                              ...
# 34691               5.0                              Yes
# 34690               4.0                               No
# 34688               2.0                               No
# 34712               4.0                              Yes
# 93799               2.0                               No
#
# [93800 rows x 19 columns]

# %%
#profession
train_df['Profession'] = np.where(train_df['Profession'].isna() & train_df['Working Professional or Student'] == 'Working Professional', 1, train_df['Profession'])
test_df['Profession'] = np.where(test_df['Profession'].isna() & test_df['Working Professional or Student'] == 'Working Professional', 1, test_df['Profession'])

# %%
# Fill missing values only for numeric columns
numeric_cols = train_df.select_dtypes(include=['number']).columns
train_df[numeric_cols] = train_df[numeric_cols].fillna(train_df[numeric_cols].mean())

#train_df[numeric_cols] = train_df[numeric_cols].fillna(0)

numeric_cols_test = test_df.select_dtypes(include=['number']).columns
test_df[numeric_cols_test] = test_df[numeric_cols_test].fillna(test_df[numeric_cols_test].mean())

#test_df[numeric_cols_test] = test_df[numeric_cols_test].fillna(0)

#inny sposób

#imputer = KNNImputer(n_neighbors=5)

#train_df[numeric_cols] = imputer.fit_transform(train_df[numeric_cols])
#test_df[numeric_cols] = imputer.fit_transform(test_df[numeric_cols_test])

# %%
# One-hot encode categorical variables
train_df = pd.get_dummies(train_df, columns=train_df.select_dtypes(include=['object']).columns)
test_df = pd.get_dummies(test_df, columns=test_df.select_dtypes(include=['object']).columns)

# %%
# Align the train and test dataframes by the columns
train_df, test_df = train_df.align(test_df, join='left', axis=1, fill_value=0)

# Ensure 'Depression' column is not in the test set
if 'Depression' in test_df.columns:
    test_df = test_df.drop(columns=['Depression'])

# %%
# Select features and target
X_train = train_df.drop(columns=['id', 'Depression'])
y_train = train_df['Depression']
X_test = test_df.drop(columns=['id'])

# %%
# Train a Logistic Regression model
model = LogisticRegression(max_iter=2000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
# Print the accuracy score on the training data
train_predictions = model.predict(X_train)
train_accuracy = accuracy_score(y_train, train_predictions)
print(f'Training Accuracy: {train_accuracy:.4f}')
# Out:
# Training Accuracy: 0.9402

# %%
# Make predictions
predictions = model.predict(X_test)

# Create submission file
submission = pd.DataFrame({
    'id': test_df['id'],
    'Depression': predictions
})
submission.to_csv('submission.csv', index=False)
